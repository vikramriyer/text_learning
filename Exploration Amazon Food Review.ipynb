# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
import re
import HTMLParser
import string
import itertools
import time
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Reviews.csv')
print df.columns
df.drop('Id',axis=1, inplace=True)
# Out:
# Index([u'Id', u'ProductId', u'UserId', u'ProfileName', u'HelpfulnessNumerator',
#        u'HelpfulnessDenominator', u'Score', u'Time', u'Summary', u'Text'],
#       dtype='object')

# %% [markdown]
# Use the below code if you want to see the full text
#
# **pd.options.display.max_colwidth = 1000**

# %% [markdown]
# Before going ahead with the analysis, we will drop rows having scores as 3 and mark Score of 1,2 as bad and 4,5 as good. This is to make the dataset a binary classification dataset which we will analyze later having multiple classes

# %%
len(df[df.Score == 3])
# Out:
# 42640

# %%
len(df)
# Out:
# 568454

# %%
df.drop(df[df.Score == 3].index, inplace=True)

# %%
len(df[df.Score == 3])
# Out:
# 0

# %%
len(df)
# Out:
# 525814

# %%
# lambda function to mark scores as bad or good depending on the Score
f = lambda x: 'bad' if x['Score'] < 3 else 'good'

# %%
df['Rating'] = df.apply(f, axis=1)

# %%
df.head(2)
# Out:
#     ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 0  B001E4KFG0  A3SGXH7AUHU8GW  delmartian                     1
# 1  B00813GRG4  A1D87F6ZCVE5NK      dll pa                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
#
#                                                 Text Rating
# 0  I have bought several of the Vitality canned d...   good
# 1  Product arrived labeled as Jumbo Salted Peanut...    bad

# %% [markdown]
# ** Let's also convert time to readable form **

# %%
# I have checked and the hour, minute, second component are same for all and hence converting to d, m, y
time_f = lambda x: datetime.datetime.fromtimestamp(x['Time']).strftime('%Y-%m-%d')

# %%
df['Readable_Time'] = df.apply(time_f, axis=1)

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# 1. Let's group by products, to find the unique products and the count for each one as well, so that we will be able to find top n products on reviews

# %%
group_by_products = pd.DataFrame({'count' : df.groupby( [ "ProductId"] ).size()}).reset_index()

# %% [markdown]
# We could have simple run the below code to find the total count, <br>
# __len(df.groupby(['ProductId']).size())__ <br>
# However, we require the grouped dataframe to draw some insights

# %%
print "We have a total of '{}' unique products in out dataset".format(len(group_by_products))
# Out:
# We have a total of '72005' unique products in out dataset

# %%
top_20_products_with_reviews = group_by_products.sort_values(by='count',ascending=False).head(20)['ProductId']

# %%
top_20_products_with_reviews
# Out:
# 69057    B007JFMH8M
# 41160    B002QWP89S
# 36919    B0026RQTGE
# 41154    B002QWHJOU
# 41161    B002QWP8H0
# 44997    B003B3OOPA
# 27918    B001EO5Q64
# 16573    B000NMJWZO
# 34331    B001RVFEP2
# 36815    B0026KNQSA
# 22733    B0013NUGDE
# 66847    B006HYLW32
# 69207    B007M832YY
# 19993    B000VK8AVK
# 69208    B007M83302
# 36819    B0026KPDG8
# 34332    B001RVFERK
# 64031    B005K4Q37A
# 64030    B005K4Q34S
# 64033    B005K4Q4LK
# Name: ProductId, dtype: object

# %%
for i in top_20_products_with_reviews:
    print df[df['ProductId'] == i][['UserId','Summary','Time']].head(1)
# Out:
#                 UserId     Summary        Time
# 562970  A368Z46FIKHSEZ  Delicious!  1343433600
#                UserId                                          Summary  \
# 20982  A21U4DR8M6I9QN  addictive! but works for night coughing in dogs
#
#              Time
# 20982  1318896000
#                UserId                                          Summary  \
# 74631  A21U4DR8M6I9QN  addictive! but works for night coughing in dogs
#
#              Time
# 74631  1318896000
#                 UserId                                          Summary  \
# 329412  A21U4DR8M6I9QN  addictive! but works for night coughing in dogs
#
#               Time
# 329412  1318896000
#                 UserId                                          Summary  \
# 355503  A21U4DR8M6I9QN  addictive! but works for night coughing in dogs
#
#               Time
# 355503  1318896000
#                 UserId                        Summary        Time
# 367524  A2X674TN3P7AVU  Taste good, great with honey!  1330473600
#                 UserId                                       Summary  \
# 189339  A2H5ROZZC74XN1  GREAT COCONUT OIL....Try it, you'll like it!
#
#               Time
# 189339  1176076800
#                 UserId      Summary        Time
# 259971  A2ZUOSNZ11MX7G  GF Greatest  1316822400
#                 UserId        Summary        Time
# 341220  A21SYVGVNG8RAS  Yummy snacks!  1298851200
#                 UserId        Summary        Time
# 344205  A21SYVGVNG8RAS  Yummy snacks!  1298851200
#                UserId        Summary        Time
# 23688  A21SYVGVNG8RAS  Yummy snacks!  1298851200
#                 UserId        Summary        Time
# 547326  A21SYVGVNG8RAS  Yummy snacks!  1298851200
#                 UserId        Summary        Time
# 359288  A21SYVGVNG8RAS  Yummy snacks!  1298851200
#                 UserId        Summary        Time
# 277140  A21SYVGVNG8RAS  Yummy snacks!  1298851200
#                UserId        Summary        Time
# 30701  A21SYVGVNG8RAS  Yummy snacks!  1298851200
#                 UserId        Summary        Time
# 413542  A21SYVGVNG8RAS  Yummy snacks!  1298851200
#                 UserId        Summary        Time
# 485256  A21SYVGVNG8RAS  Yummy snacks!  1298851200
#                 UserId                             Summary        Time
# 120293  A2XP9IN4JOMROD  Low Quality. High Calorie and Fat.  1332115200
#                 UserId                             Summary        Time
# 531605  A2XP9IN4JOMROD  Low Quality. High Calorie and Fat.  1332115200
#                 UserId                             Summary        Time
# 405241  A2XP9IN4JOMROD  Low Quality. High Calorie and Fat.  1332115200

# %% [markdown]
# The above result tells us is that, a same product can have different ProductId's, however, the UserId's are same and the same user has commented on all similar products having different product id's
#
# __Conclusion__:
#  - or maybe the users are copy pasting the same summary/texts for multiple such Product Id's
#  - or something wierd is going on!

# %%
word_counter = lambda x: len(x['Text'].split(' '))

# %%
df['word_count'] = df.apply(word_counter, axis=1)

# %%
df['word_count'].max()
# Out:
# 2640

# %%
df['word_count'].min()
# Out:
# 3

# %%
df.sort_values('word_count', ascending=False)
# Out:
#          ProductId              UserId  \
# 68700   B0051BWU92      A2GZG363BPADYC
# 541158  B005EF0HTK  #oc-R1ZR5L29T4LSAE
# 175972  B007TGO1U8      A2VW4FYZILSXF2
# 331318  B001P74NXM      A1WW22EAVQNM56
# 346183  B002P0Q14C      A1FLQ698D9C0C8
# 407775  B000EMAZPO       A28P0QPSXBJTN
# 209088  B00004RAMY       A9PC5HJNGD22D
# 97610   B0010EI0QG       A150QS4IZB3XJ
# 269916  B003TDYDU8      A17V9XL4CWTQ6G
# 175184  B001Z4KOK6      A17V9XL4CWTQ6G
# 10004   B000P41A28      A3A6QXIC8XCOJG
# 483159  B000634G8I      A1Z4LX3Q1YMF84
# 483159                      Cindy A. Osterhout "Cindy O"
# 248851                                          G. Zhang
# 539893                                          G. Zhang
# 247126                                         C. Fugate
# 253600                                             Iucci
# 181309                                      Dan Robinson
# 465404                                      Dan Robinson
# 137988                                      Dan Robinson
# 399081                                      Dan Robinson
# 276019                                          Drum 247
# 541046                                             losul
# 402704                 Dr. M. A. Dixon "hyper-observant"
# 348701                                 E. Mccloskey "EM"
# 501128               C. Scanlon "least helpful reviewer"
# 230035                                          G. Zhang
# 381800                               Patricia "A Reader"
# 552316                                   My2cents "bj42"
# 411014                                            Stoney
# 8756                 C. Scanlon "least helpful reviewer"
# ...                                                  ...
# 336350                                          Sweetone
# 197142                          another reader-purchaser
# 217416                           Nancy Watts "Nan Watts"
# 459486                                      Myron Slover
# 65997                                           Sweetone
# 202220                                          Teas Etc
# 394689                           Nancy Watts "Nan Watts"
# 143403                                          Sweetone
# 540600                                      T. Proefrock
# 495800                                     Donald THomas
# 281030             Glenn A. Mckngiht "Glenn A. McKnight"
# 107456                                          Teas Etc
# 107554                                      T. Proefrock
# 236344                  M. Green "mystery/suspense love"
# 419274                           Nancy Watts "Nan Watts"
# 461810             Glenn A. Mckngiht "Glenn A. McKnight"
# 206514                                 Mirielle I. Eaton
# 201631                                     Thomas W Hill
# 68442                                Two Leaves tea lady
# 184995                                           Broseph
# 202597                                    Larry Sypowicz
# 458560                     Michael A. Capilli "Dr. Mike"
# 326788                               Two Leaves tea lady
# 14893                                Two Leaves tea lady
# 80655                                         K. Stanton
# 395029                                    Larry Sypowicz
# 156286                                  Nancy Washingotn
# 234392                                Sheri L. Pritchard
# 168550                                    Seth Goldstein
# 453668                                               Bob
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 68700                      4                       4      5  1323993600
# 541158                     9                      17      1  1320019200
# 175972                    53                      54      4  1342310400
# 331318                    19                      23      5  1312243200
# 346183                     0                       2      5  1252800000
# 407775                     0                      10      4  1282089600
# 209088                   366                     371      5  1193875200
# 97610                     12                      13      5  1318377600
# 269916                     4                       6      5  1328140800
# 175184                     8                       8      5  1328140800
# 10004                      9                      20      1  1231804800
# 483159                     0                       0      4  1236038400
# 248851                     4                       8      5  1255478400
# 539893                     0                       0      5  1255478400
# 247126                    43                      43      5  1308528000
# 253600                     0                       0      5  1349136000
# 181309                    25                      29      1  1156636800
# 465404                    15                      16      1  1156636800
# 137988                    19                      26      1  1156636800
# 399081                    11                      12      1  1156636800
# 276019                     7                       7      5  1333929600
# 541046                    11                      12      2  1324339200
# 402704                     3                       3      5  1276214400
# 348701                     7                       7      4  1328400000
# 501128                    15                      17      5  1331510400
# 230035                     1                       4      5  1253923200
# 381800                     2                      10      1  1248048000
# 552316                   188                     195      1  1166140800
# 411014                     1                       1      5  1335571200
# 8756                       7                      15      5  1261699200
# ...                      ...                     ...    ...         ...
# 336350                     8                      11      5  1300406400
# 197142                     1                       1      5  1176249600
# 217416                     1                      22      2  1134172800
# 459486                     1                       1      1  1341100800
# 65997                      8                      11      5  1300406400
# 202220                     9                       9      5  1247529600
# 394689                     1                      22      2  1134172800
# 143403                     8                      11      5  1300406400
# 461810       Good price, shipping could be faster though.   good
# 206514      this seller was very accomadating and helpful   good
# 201631  <span class="tiny"> Length:: 0:43 Mins<br /><b...   good
# 68442             Smoothest green tea yet....good all day   good
# 184995                  Yeah, but they taste really good.   good
# 202597                Poor product don't waste your money    bad
# 458560                Tea lover friend raves about it....   good
# 326788            Smoothest green tea yet....good all day   good
# 14893             Smoothest green tea yet....good all day   good
# 80655         Great gift. Fast delivery. Quality product.   good
# 395029                Poor product don't waste your money    bad
# 156286                        It is an excellent product.   good
# 234392                     OUR FAVORITE! EXCELLENT ITEM!!   good
# 168550                                 they are excellent   good
# 453668                                       Not worth it    bad
#
#        Readable_Time  word_count
# 68700     2011-12-16        2640
# 541158    2011-10-31        2233
# 175972    2012-07-15        2128
# 331318    2011-08-02        2096
# 346183    2009-09-13        2075
# 407775    2010-08-18        1964
# 209088    2007-11-01        1942
# 97610     2011-10-12        1865
# 269916    2012-02-02        1863
# 175184    2012-02-02        1863
# 10004     2009-01-13        1772
# 483159    2009-03-03        1766
# 248851    2009-10-14        1736
# 539893    2009-10-14        1736
# 247126    2011-06-20        1706
# 253600    2012-10-02        1635
# 181309    2006-08-27        1629
# 465404    2006-08-27        1629
# 137988    2006-08-27        1629
# 399081    2006-08-27        1629
# 276019    2012-04-09        1623
# 541046    2011-12-20        1622
# 402704    2010-06-11        1578
# 348701    2012-02-05        1557
# 501128    2012-03-12        1539
# 230035    2009-09-26        1535
# 381800    2009-07-20        1524
# 552316    2006-12-15        1514
# 411014    2012-04-28        1513
# 8756      2009-12-25        1513
# ...              ...         ...
# 336350    2011-03-18           7
# 197142    2007-04-11           7
# 217416    2005-12-10           7
# 459486    2012-07-01           7
# 65997     2011-03-18           7
# 202220    2009-07-14           7
# 394689    2005-12-10           7
# 143403    2011-03-18           7
# 540600    2007-03-09           7
# 495800    2012-10-24           7
# 281030    2007-05-16           7
# 107456    2009-07-14           7
# 107554    2007-03-09           7
# 236344    2006-08-20           7
# 419274    2005-12-10           7
# 461810    2007-05-16           7
# 206514    2007-06-19           7
# 201631    2012-10-08           7
# 68442     2009-12-15           6
# 184995    2006-01-09           6
# 202597    2007-01-04           6
# 458560    2009-07-05           6
# 326788    2009-12-15           6
# 14893     2009-12-15           6
# 80655     2005-09-20           6
# 395029    2007-01-04           6
# 156286    2007-05-12           5
# 234392    2007-02-11           4
# 168550    2006-01-15           3
# 453668    2006-01-03           3
#
# [525814 rows x 12 columns]

# %%
# Normalize helpfullness numerator and denominator
min_help_numerator = df['HelpfulnessNumerator'].min()
max_help_numerator = df['HelpfulnessNumerator'].max()
min_help_denominator = df['HelpfulnessNumerator'].min()
max_help_denominator = df['HelpfulnessNumerator'].max()

df['HelpfulnessNumerator_N'] = (df['HelpfulnessNumerator'] - min_help_numerator)/(max_help_numerator - min_help_numerator)
df['HelpfulnessDenominator_N'] = (df['HelpfulnessDenominator'] - min_help_denominator)/(max_help_denominator - min_help_denominator)

# %%
df['HelpfulnessIndicator'] = df['HelpfulnessNumerator']*df['HelpfulnessNumerator_N']/df['HelpfulnessDenominator']

# %% [markdown]
# ### Longer reviews are more helpful

# %%
df.sort_values('HelpfulnessIndicator', ascending=False)[['word_count','Rating','Score','HelpfulnessIndicator']].head(20)
# Out:
#         word_count Rating  Score  HelpfulnessIndicator
# 190733        1223   good      5              0.986333
# 566779         346   good      5              0.925012
# 235722         801    bad      1              0.655064
# 96104          442   good      5              0.642051
# 373575         442   good      5              0.642051
# 293135         442   good      5              0.642051
# 116802         442   good      5              0.642051
# 130478         442   good      5              0.642051
# 210511         442   good      5              0.642051
# 297366         442   good      5              0.642051
# 385450         442   good      5              0.642051
# 467800         442   good      5              0.642051
# 287184         442   good      5              0.642051
# 88407           75   good      5              0.615493
# 303074         206   good      5              0.614395
# 375916         206   good      5              0.614395
# 190734         550    bad      2              0.591534
# 433675         394   good      5              0.554422
# 373776         394   good      5              0.554422
# 373576         272   good      5              0.539321

# %% [markdown]
# ### Positive review are common

# %%
len(df[df['Rating'] == 'good'])
# Out:
# 443777

# %%
len(df[df['Rating'] == 'bad'])
# Out:
# 82037

# %% [markdown]
# ### Positive reviews are shorter

# %%
df.sort_values('word_count', ascending=False)[['Rating','word_count','HelpfulnessIndicator']].head(20)
# Out:
#        Rating  word_count  HelpfulnessIndicator
# 68700    good        2640              0.004619
# 541158    bad        2233              0.005502
# 175972   good        2128              0.060068
# 331318   good        2096              0.018124
# 346183   good        2075              0.000000
# 407775   good        1964              0.000000
# 209088   good        1942              0.416937
# 97610    good        1865              0.012791
# 269916   good        1863              0.003079
# 175184   good        1863              0.009238
# 10004     bad        1772              0.004677
# 483159   good        1766                   NaN
# 248851   good        1736              0.002309
# 539893   good        1736                   NaN
# 247126   good        1706              0.049654
# 253600   good        1635                   NaN
# 181309    bad        1629              0.024887
# 465404    bad        1629              0.016238
# 137988    bad        1629              0.016033
# 399081    bad        1629              0.011644

# %%
group_by_users = pd.DataFrame({'Count' : df.groupby( ['UserId','word_count','Rating'] ).size()}).reset_index()

# %%
group_by_users.sort_values(by='Count',ascending=False).head(20)
# Out:
#                 UserId  word_count Rating  Count
# 268054  A3TVZM3ZIXG8YW         864    bad    199
# 76556   A1TMAVN4CEM8U8         514   good    137
# 119112  A29JUMRL1US6YP         346   good     56
# 206334  A36JDIN9RAAIEC         173   good     51
# 119113  A29JUMRL1US6YP         347   good     46
# 256538  A3PJZ8TU8FDQ1K         242   good     42
# 303019   AF3BYMPWKWO8F         203    bad     41
# 79341   A1UQBFCERIP7VJ         109   good     38
# 107799  A25C5MVVCIYT5D         280   good     34
# 95708   A20P8VC55KPPCT         105   good     31
# 355084   AYQ8RLE0K6RU8         207   good     31
# 29432   A1BD342U8BF3UC          33   good     28
# 106007  A24PZR4W555WQI          32   good     28
# 215949  A3A1OA237FOZFK         398   good     28
# 339926   AT0J9IP8XD95F         204   good     28
# 323485   AMQ1MEG334SAP          64    bad     28
# 164024  A2QJF1B00I7BT7          55   good     27
# 314450   AJD41FBJD9010         269   good     27
# 341143   ATIHDHZYNQ0EI          30   good     27
# 256496  A3PJRR03ZAFWGR         147    bad     26
